# %%
### This code develops classification trees based on before and after COVID-19 mandate periods for face mask behaviour binary in Australia.

# Load the pacakges.
import pandas as pd
import numpy as np
import optuna
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

# Set a seed for reproducibility with optuna.
sampler = optuna.samplers.TPESampler(seed=1826179)

# Read the data and select the subset within_mandates == 0.
df1 = pd.read_csv("./face_mask_ausmand.csv")
df = df1[df1['within_mandates'] == 0]
# Drop the following columns to not be added as an explanatory variable.
X = df.drop(columns=["RecordNo",
                     "face_mask_behaviour_scale",
                     "protective_behaviour_scale",
                     "face_mask_behaviour_binary",
                     "protective_behaviour_binary",
                     "protective_behaviour_nomask_scale",
                     "protective_behaviour_nomask_binary",
                     "endtime",
                    "within_mandates"])
# Select the response variable.
y = df['face_mask_behaviour_binary'].map({'Yes': 1, 'No': 0})
# Split the dataset into a training and testing set (0.7, 0.3).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1826179)

# Define the function for the study which will use the optuna package. Google AI was used to help with this function.
def objective(trial):
    # Select paramaters to be optimised.
    param = {
        'max_depth': trial.suggest_int('max_depth', 1, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 25),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy'])
    }
    clf = DecisionTreeClassifier(**param)
    # Cross validation. (Google AI use to help with this step.)
    score = cross_val_score(clf, X_train, y_train, cv=3).mean()
    return score
    
# Create a study to maximise the score value with 50 trials.
study = optuna.create_study(direction='maximize', sampler = sampler)
study.optimize(objective, n_trials=50)

# Train the best model using the training set specified.
best_params = study.best_params
clf = DecisionTreeClassifier(**best_params)
clf.fit(X_train, y_train)

# Get prediction values with the test values. This is to get model metric values.
y_pred = clf.predict(X_test)
# This particular step Google AI was used to help calculate the ROC AUC.
y_prob = clf.predict_proba(X_test)[:, 1]

#Calculate the metrics and save in a dictionary.
metrics = {
    "Accuracy": round(accuracy_score(y_test, y_pred),4),
    "F1 Score": round(f1_score(y_test, y_pred),4),
    "Recall": round(recall_score(y_test, y_pred),4),
    "Precision": round(precision_score(y_test, y_pred),4),
    "ROC AUC": round(roc_auc_score(y_test, y_prob),4)
}
print(metrics)
# Out:
# [I 2026-05-07 14:08:20,463] A new study created in memory with name: no-name-dc81b439-bbec-444c-add9-f09d75f84766
# [I 2026-05-07 14:08:20,549] Trial 0 finished with value: 0.7506886863730312 and parameters: {'max_depth': 12, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 0 with value: 0.7506886863730312.
# [I 2026-05-07 14:08:20,652] Trial 1 finished with value: 0.7334471948045392 and parameters: {'max_depth': 20, 'min_samples_split': 4, 'criterion': 'entropy'}. Best is trial 0 with value: 0.7506886863730312.
# [I 2026-05-07 14:08:20,754] Trial 2 finished with value: 0.7292157003309453 and parameters: {'max_depth': 18, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 0 with value: 0.7506886863730312.
# [I 2026-05-07 14:08:20,848] Trial 3 finished with value: 0.750794036593545 and parameters: {'max_depth': 17, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 3 with value: 0.750794036593545.
# [I 2026-05-07 14:08:22,807] Trial 35 finished with value: 0.7717375865959347 and parameters: {'max_depth': 9, 'min_samples_split': 12, 'criterion': 'entropy'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:22,844] Trial 36 finished with value: 0.7797761876685133 and parameters: {'max_depth': 4, 'min_samples_split': 25, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:22,926] Trial 37 finished with value: 0.7581986904487658 and parameters: {'max_depth': 12, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:22,963] Trial 38 finished with value: 0.7797761876685133 and parameters: {'max_depth': 4, 'min_samples_split': 13, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,013] Trial 39 finished with value: 0.783796377590226 and parameters: {'max_depth': 6, 'min_samples_split': 6, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,078] Trial 40 finished with value: 0.7700456734654644 and parameters: {'max_depth': 8, 'min_samples_split': 15, 'criterion': 'entropy'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,135] Trial 41 finished with value: 0.786757292691977 and parameters: {'max_depth': 7, 'min_samples_split': 18, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,178] Trial 42 finished with value: 0.7835841333103503 and parameters: {'max_depth': 5, 'min_samples_split': 20, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,236] Trial 43 finished with value: 0.7869688321758569 and parameters: {'max_depth': 7, 'min_samples_split': 18, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,307] Trial 44 finished with value: 0.7626414223508129 and parameters: {'max_depth': 9, 'min_samples_split': 2, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,382] Trial 45 finished with value: 0.759785219797008 and parameters: {'max_depth': 10, 'min_samples_split': 17, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,400] Trial 46 finished with value: 0.7537550188187243 and parameters: {'max_depth': 1, 'min_samples_split': 15, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,490] Trial 47 finished with value: 0.7505816916285272 and parameters: {'max_depth': 19, 'min_samples_split': 20, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,535] Trial 48 finished with value: 0.7839011908233143 and parameters: {'max_depth': 5, 'min_samples_split': 13, 'criterion': 'entropy'}. Best is trial 7 with value: 0.7872859232505353.
# [I 2026-05-07 14:08:23,599] Trial 49 finished with value: 0.769516539481195 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'criterion': 'gini'}. Best is trial 7 with value: 0.7872859232505353.
# {'Accuracy': 0.7744, 'F1 Score': 0.3824, 'Recall': 0.2864, 'Precision': 0.5752, 'ROC AUC': 0.7694}

# %%
# Load the pacakges.
import pandas as pd
import numpy as np
import optuna
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

# Set a seed for reproducibility with optuna.
sampler = optuna.samplers.TPESampler(seed=1826179)

# Read the data and select the subset within_mandates == 1.
df1 = pd.read_csv("./face_mask_ausmand.csv")
df = df1[df1['within_mandates'] == 1]
# Drop the following columns to not be added as an explanatory variable.
X = df.drop(columns=["RecordNo",
                     "face_mask_behaviour_scale",
                     "protective_behaviour_scale",
                     "face_mask_behaviour_binary",
                     "protective_behaviour_binary",
                     "protective_behaviour_nomask_scale",
                     "protective_behaviour_nomask_binary",
                     "endtime",
                    "within_mandates"])
# Select the response variable.
y = df['face_mask_behaviour_binary'].map({'Yes': 1, 'No': 0})
# Split the dataset into a training and testing set (0.7, 0.3).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1826179)

# Define the function for the study which will use the optuna package. Google AI was used to help with this function.
def objective(trial):
    # Select paramaters to be optimised.
    param = {
        'max_depth': trial.suggest_int('max_depth', 1, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 25),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy'])
    }
    clf = DecisionTreeClassifier(**param)
    # Cross validation. (Google AI use to help with this step.)
    score = cross_val_score(clf, X_train, y_train, cv=3).mean()
    return score
    
# Create a study to maximise the score value with 50 trials.
study = optuna.create_study(direction='maximize', sampler = sampler)
study.optimize(objective, n_trials=50)

# Train the best model using the training set specified.
best_params = study.best_params
clf = DecisionTreeClassifier(**best_params)
clf.fit(X_train, y_train)

# Get prediction values with the test values. This is to get model metric values.
y_pred = clf.predict(X_test)
# This particular step Google AI was used to help calculate the ROC AUC.
y_prob = clf.predict_proba(X_test)[:, 1]

#Calculate the metrics and save in a dictionary.
metrics = {
    "Accuracy": round(accuracy_score(y_test, y_pred),4),
    "F1 Score": round(f1_score(y_test, y_pred),4),
    "Recall": round(recall_score(y_test, y_pred),4),
    "Precision": round(precision_score(y_test, y_pred),4),
    "ROC AUC": round(roc_auc_score(y_test, y_prob),4)
}
print(metrics)
# Out:
# [I 2026-05-07 14:08:23,688] A new study created in memory with name: no-name-73ece8c2-ad7a-4147-ab97-b408f080f00b
# [I 2026-05-07 14:08:23,822] Trial 0 finished with value: 0.8068769882565316 and parameters: {'max_depth': 12, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8068769882565316.
# [I 2026-05-07 14:08:23,980] Trial 1 finished with value: 0.7714564786689891 and parameters: {'max_depth': 20, 'min_samples_split': 4, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8068769882565316.
# [I 2026-05-07 14:08:24,137] Trial 2 finished with value: 0.7722847931412226 and parameters: {'max_depth': 18, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8068769882565316.
# [I 2026-05-07 14:08:24,281] Trial 3 finished with value: 0.7913417902051124 and parameters: {'max_depth': 17, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8068769882565316.
# [I 2026-05-07 14:08:27,118] Trial 35 finished with value: 0.8260028982925203 and parameters: {'max_depth': 6, 'min_samples_split': 22, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,193] Trial 36 finished with value: 0.8260028982925203 and parameters: {'max_depth': 6, 'min_samples_split': 23, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,249] Trial 37 finished with value: 0.8028723979488707 and parameters: {'max_depth': 4, 'min_samples_split': 23, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,325] Trial 38 finished with value: 0.8260028982925203 and parameters: {'max_depth': 6, 'min_samples_split': 22, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,350] Trial 39 finished with value: 0.7445971114222351 and parameters: {'max_depth': 1, 'min_samples_split': 22, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,405] Trial 40 finished with value: 0.8028723979488707 and parameters: {'max_depth': 4, 'min_samples_split': 25, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,481] Trial 41 finished with value: 0.8257957302792615 and parameters: {'max_depth': 6, 'min_samples_split': 20, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,547] Trial 42 finished with value: 0.8188221608785206 and parameters: {'max_depth': 5, 'min_samples_split': 20, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,612] Trial 43 finished with value: 0.8190983848961988 and parameters: {'max_depth': 5, 'min_samples_split': 23, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,688] Trial 44 finished with value: 0.8257957302792615 and parameters: {'max_depth': 6, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,764] Trial 45 finished with value: 0.8257957302792615 and parameters: {'max_depth': 6, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,809] Trial 46 finished with value: 0.8037699400643085 and parameters: {'max_depth': 3, 'min_samples_split': 21, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,885] Trial 47 finished with value: 0.8257957302792615 and parameters: {'max_depth': 6, 'min_samples_split': 19, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,921] Trial 48 finished with value: 0.7539184848506174 and parameters: {'max_depth': 2, 'min_samples_split': 22, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# [I 2026-05-07 14:08:27,976] Trial 49 finished with value: 0.8028723979488707 and parameters: {'max_depth': 4, 'min_samples_split': 20, 'criterion': 'entropy'}. Best is trial 35 with value: 0.8260028982925203.
# {'Accuracy': 0.8226, 'F1 Score': 0.8808, 'Recall': 0.9193, 'Precision': 0.8454, 'ROC AUC': 0.8444}
