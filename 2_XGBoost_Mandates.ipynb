# %%
### This code develops XGBoost based on before and after COVID-19 mandate periods for face mask behaviour binary in Australia.

# Load the pacakges.
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, roc_curve
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Set a seed for reproducibility with optuna.
sampler = optuna.samplers.TPESampler(seed=1826179)

# Read the data and select the subset within_mandates == 0.
df1 = pd.read_csv("./face_mask_ausmand.csv")
df = df1[df1['within_mandates'] == 0]
# Drop the following columns to not be added as an explanatory variable.
X = df.drop(columns=["RecordNo",
                     "face_mask_behaviour_scale",
                     "protective_behaviour_scale",
                     "face_mask_behaviour_binary",
                     "protective_behaviour_binary",
                     "protective_behaviour_nomask_scale",
                     "protective_behaviour_nomask_binary",
                     "endtime",
                    "within_mandates"])
# Select the response variable.
y = df['face_mask_behaviour_binary'].map({'Yes': 1, 'No': 0})
# Split the dataset into a training and testing set (0.7, 0.3).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1826179)

# Define the function for the study which will use the optuna package. Google AI was used to help with this function.
def objective(trial):
    # Select paramaters to be optimised.
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 1, 20),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.4, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "objective": "binary:logistic",
    }
    # Create and fit model based on accuracy. (Google AI use to help with this step.)
    model = xgb.XGBClassifier(**param)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return accuracy_score(y_test, preds)

# Create a study to maximise the score value with 20 trials.
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)

#print(f"Best parameters: {study.best_params}")

# Fit the best model based on optimised hyper-parameters.
best_model = xgb.XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)

# Calculate the model metrics.
y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]
print(f"Recall: {recall_score(y_test, y_pred):.4f}")
print(f"Precision: {precision_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"F1 Score: {f1_score(y_test, y_pred):.4f}")
print(f"ROC AUC: {roc_auc_score(y_test, y_proba):.4f}")
# Out:
# [I 2026-05-07 14:07:00,188] A new study created in memory with name: no-name-794aa4ea-1b14-47d3-b52a-db685bbe5812
# [I 2026-05-07 14:07:00,594] Trial 0 finished with value: 0.7956564659427443 and parameters: {'n_estimators': 631, 'max_depth': 2, 'learning_rate': 0.014942233747549296, 'subsample': 0.48975106610631114, 'colsample_bytree': 0.9992333232357645}. Best is trial 0 with value: 0.7956564659427443.
# [I 2026-05-07 14:07:01,216] Trial 1 finished with value: 0.8065153010858835 and parameters: {'n_estimators': 181, 'max_depth': 14, 'learning_rate': 0.23463769609101384, 'subsample': 0.927696434292259, 'colsample_bytree': 0.5295783788187518}. Best is trial 1 with value: 0.8065153010858835.
# [I 2026-05-07 14:07:01,657] Trial 2 finished with value: 0.8079960513326753 and parameters: {'n_estimators': 129, 'max_depth': 14, 'learning_rate': 0.16895942017427154, 'subsample': 0.8320626220361877, 'colsample_bytree': 0.8187980858265136}. Best is trial 2 with value: 0.8079960513326753.
# [I 2026-05-07 14:07:04,868] Trial 3 finished with value: 0.8099703849950641 and parameters: {'n_estimators': 794, 'max_depth': 20, 'learning_rate': 0.015489978110688737, 'subsample': 0.43241062385154055, 'colsample_bytree': 0.6230802270677887}. Best is trial 3 with value: 0.8099703849950641.
# [I 2026-05-07 14:07:05,977] Trial 4 finished with value: 0.8134254689042448 and parameters: {'n_estimators': 289, 'max_depth': 16, 'learning_rate': 0.04409792193182924, 'subsample': 0.7302053929228453, 'colsample_bytree': 0.5248821177745304}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:07,502] Trial 5 finished with value: 0.8082428430404739 and parameters: {'n_estimators': 356, 'max_depth': 19, 'learning_rate': 0.030040428115744127, 'subsample': 0.586290243002886, 'colsample_bytree': 0.7014956435636142}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:08,401] Trial 6 finished with value: 0.8109575518262586 and parameters: {'n_estimators': 532, 'max_depth': 7, 'learning_rate': 0.020234495256003706, 'subsample': 0.7102319895299062, 'colsample_bytree': 0.9381493436045977}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:09,215] Trial 7 finished with value: 0.7993583415597236 and parameters: {'n_estimators': 661, 'max_depth': 5, 'learning_rate': 0.20953658949651843, 'subsample': 0.5104083832991025, 'colsample_bytree': 0.8591095929724175}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:11,258] Trial 8 finished with value: 0.8040473840078973 and parameters: {'n_estimators': 894, 'max_depth': 10, 'learning_rate': 0.08367703595274557, 'subsample': 0.9194660744315741, 'colsample_bytree': 0.9605158762865356}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:12,527] Trial 9 finished with value: 0.81071076011846 and parameters: {'n_estimators': 513, 'max_depth': 10, 'learning_rate': 0.017247902628940253, 'subsample': 0.9320016715321715, 'colsample_bytree': 0.5789728701595327}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:13,740] Trial 10 finished with value: 0.8062685093780849 and parameters: {'n_estimators': 332, 'max_depth': 16, 'learning_rate': 0.07114235629758434, 'subsample': 0.7270363017917683, 'colsample_bytree': 0.6774223401308195}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:14,351] Trial 11 finished with value: 0.81071076011846 and parameters: {'n_estimators': 427, 'max_depth': 6, 'learning_rate': 0.03404408728231725, 'subsample': 0.6829345397123682, 'colsample_bytree': 0.8083490630759849}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:14,788] Trial 12 finished with value: 0.81071076011846 and parameters: {'n_estimators': 254, 'max_depth': 7, 'learning_rate': 0.0363254792749642, 'subsample': 0.7359204329231428, 'colsample_bytree': 0.8998835442044473}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:15,023] Trial 13 finished with value: 0.7798617966436328 and parameters: {'n_estimators': 507, 'max_depth': 1, 'learning_rate': 0.024890507711798866, 'subsample': 0.6336029818712017, 'colsample_bytree': 0.5039285159892373}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:17,159] Trial 14 finished with value: 0.8114511352418559 and parameters: {'n_estimators': 707, 'max_depth': 13, 'learning_rate': 0.052722369234450915, 'subsample': 0.8063707654161858, 'colsample_bytree': 0.7559230220670565}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:19,396] Trial 15 finished with value: 0.8094768015794669 and parameters: {'n_estimators': 754, 'max_depth': 16, 'learning_rate': 0.11481951184876905, 'subsample': 0.8051928342067322, 'colsample_bytree': 0.7421477115473545}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:22,248] Trial 16 finished with value: 0.8099703849950641 and parameters: {'n_estimators': 979, 'max_depth': 13, 'learning_rate': 0.045950806062295055, 'subsample': 0.8332459585955511, 'colsample_bytree': 0.6383318189434823}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:24,595] Trial 17 finished with value: 0.8099703849950641 and parameters: {'n_estimators': 660, 'max_depth': 17, 'learning_rate': 0.058298557588373746, 'subsample': 0.7765526528188043, 'colsample_bytree': 0.7249870790402573}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:26,789] Trial 18 finished with value: 0.812685093780849 and parameters: {'n_estimators': 784, 'max_depth': 11, 'learning_rate': 0.011231587013050175, 'subsample': 0.9990026415110373, 'colsample_bytree': 0.7897609068914361}. Best is trial 4 with value: 0.8134254689042448.
# [I 2026-05-07 14:07:29,280] Trial 19 finished with value: 0.808736426456071 and parameters: {'n_estimators': 892, 'max_depth': 11, 'learning_rate': 0.01057584053553404, 'subsample': 0.8792591762460502, 'colsample_bytree': 0.794491752435857}. Best is trial 4 with value: 0.8134254689042448.
# Recall: 0.3978
# Precision: 0.7094
# Accuracy: 0.8134
# F1 Score: 0.5097
# ROC AUC: 0.8314

# %%
# Load the pacakges.
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, roc_curve
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Set a seed for reproducibility with optuna.
sampler = optuna.samplers.TPESampler(seed=1826179)

# Read the data and select the subset within_mandates == 1.
df1 = pd.read_csv("./face_mask_ausmand.csv")
df = df1[df1['within_mandates'] == 1]
# Drop the following columns to not be added as an explanatory variable.
X = df.drop(columns=["RecordNo",
                     "face_mask_behaviour_scale",
                     "protective_behaviour_scale",
                     "face_mask_behaviour_binary",
                     "protective_behaviour_binary",
                     "protective_behaviour_nomask_scale",
                     "protective_behaviour_nomask_binary",
                     "endtime",
                    "within_mandates"])
# Select the response variable.
y = df['face_mask_behaviour_binary'].map({'Yes': 1, 'No': 0})
# Split the dataset into a training and testing set (0.7, 0.3).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1826179)

# Define the function for the study which will use the optuna package. Google AI was used to help with this function.
def objective(trial):
    # Select paramaters to be optimised.
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 1, 20),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.4, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "objective": "binary:logistic",
    }
    # Create and fit model based on accuracy. (Google AI use to help with this step.)
    model = xgb.XGBClassifier(**param)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return accuracy_score(y_test, preds)

# Create a study to maximise the score value with 20 trials.
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=20)

#print(f"Best parameters: {study.best_params}")

# Fit the best model based on optimised hyper-parameters.
best_model = xgb.XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)

# Calculate the model metrics.
y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]
print(f"Recall: {recall_score(y_test, y_pred):.4f}")
print(f"Precision: {precision_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"F1 Score: {f1_score(y_test, y_pred):.4f}")
print(f"ROC AUC: {roc_auc_score(y_test, y_proba):.4f}")
# Out:
# [I 2026-05-07 14:07:30,452] A new study created in memory with name: no-name-8ca363f0-a4e6-46e5-af74-cac153b2f45f
# [I 2026-05-07 14:07:30,895] Trial 0 finished with value: 0.820715206185567 and parameters: {'n_estimators': 631, 'max_depth': 2, 'learning_rate': 0.014942233747549296, 'subsample': 0.48975106610631114, 'colsample_bytree': 0.9992333232357645}. Best is trial 0 with value: 0.820715206185567.
# [I 2026-05-07 14:07:31,549] Trial 1 finished with value: 0.8447164948453608 and parameters: {'n_estimators': 181, 'max_depth': 14, 'learning_rate': 0.23463769609101384, 'subsample': 0.927696434292259, 'colsample_bytree': 0.5295783788187518}. Best is trial 1 with value: 0.8447164948453608.
# [I 2026-05-07 14:07:32,054] Trial 2 finished with value: 0.8445554123711341 and parameters: {'n_estimators': 129, 'max_depth': 14, 'learning_rate': 0.16895942017427154, 'subsample': 0.8320626220361877, 'colsample_bytree': 0.8187980858265136}. Best is trial 1 with value: 0.8447164948453608.
# [I 2026-05-07 14:07:35,847] Trial 3 finished with value: 0.850354381443299 and parameters: {'n_estimators': 794, 'max_depth': 20, 'learning_rate': 0.015489978110688737, 'subsample': 0.43241062385154055, 'colsample_bytree': 0.6230802270677887}. Best is trial 3 with value: 0.850354381443299.
# [I 2026-05-07 14:07:37,149] Trial 4 finished with value: 0.8508376288659794 and parameters: {'n_estimators': 289, 'max_depth': 16, 'learning_rate': 0.04409792193182924, 'subsample': 0.7302053929228453, 'colsample_bytree': 0.5248821177745304}. Best is trial 4 with value: 0.8508376288659794.
# [I 2026-05-07 14:07:38,927] Trial 5 finished with value: 0.8489046391752577 and parameters: {'n_estimators': 356, 'max_depth': 19, 'learning_rate': 0.030040428115744127, 'subsample': 0.586290243002886, 'colsample_bytree': 0.7014956435636142}. Best is trial 4 with value: 0.8508376288659794.
# [I 2026-05-07 14:07:39,904] Trial 6 finished with value: 0.8500322164948454 and parameters: {'n_estimators': 532, 'max_depth': 7, 'learning_rate': 0.020234495256003706, 'subsample': 0.7102319895299062, 'colsample_bytree': 0.9381493436045977}. Best is trial 4 with value: 0.8508376288659794.
# [I 2026-05-07 14:07:40,787] Trial 7 finished with value: 0.8307023195876289 and parameters: {'n_estimators': 661, 'max_depth': 5, 'learning_rate': 0.20953658949651843, 'subsample': 0.5104083832991025, 'colsample_bytree': 0.8591095929724175}. Best is trial 4 with value: 0.8508376288659794.
# [I 2026-05-07 14:07:43,039] Trial 8 finished with value: 0.8492268041237113 and parameters: {'n_estimators': 894, 'max_depth': 10, 'learning_rate': 0.08367703595274557, 'subsample': 0.9194660744315741, 'colsample_bytree': 0.9605158762865356}. Best is trial 4 with value: 0.8508376288659794.
